# %% [markdown]
# # Cadenas de texto

# %%
cadena = """ 
este es un texto largo
- punto 1: 'Comillas simples'
- punto 2: \"Comillas dobles\"
- punto 3
"""

print(len(cadena))
# Out:
# 94

# %%
larga = "Alístate en la marina"
print(len(larga))
# Out:
# 21

# %% [markdown]
# ## Slicing

# %%
print(larga[::-1])
print(larga[3])
# Out:
# aniram al ne etatsílA
# s

# %%
nombre = "Paco"
apellido = "López"
completo = nombre + " " + apellido
print(completo)
apellido
# Out:
# Paco López
# 'López'

# %%
ruta = "C:\\Users\\integ\\Desktop\\Rafa Perez Lopez\\IFCD0210\\UF1844"
print(ruta)
# Out:
# C:\Users\integ\Desktop\Rafa Perez Lopez\IFCD0210\UF1844

# %% [markdown]
# ## Cadenas 'r' (raw)

# %%
ruta = r'C:\Users\integ\Desktop\Rafa Perez Lopez\IFCD0210\UF1844'
print(ruta)
# Out:
# C:\Users\integ\Desktop\Rafa Perez Lopez\IFCD0210\UF1844

# %% [markdown]
# ## Cadenas 'f' (format)

# %%
cadena_f = f'Mi nombre es {nombre} y mi apellido es {apellido}, por lo que mi nombre completo es {completo}'
print(cadena_f)
# Out:
# Mi nombre es Paco y mi apellido es López, por lo que mi nombre completo es Paco López

# %% [markdown]
# ## Condicionales

# %%
x = 9
if x > 5:
    print("Aprobati con tomati")
else:
    print("Calabazas")
# Out:
# Aprobati con tomati

# %% [markdown]
# ## Entrada de dato por teclado

# %%
dato = input("dame un numero")
numero = int(dato)
if numero < 0:
    print('Negativo')
elif numero > 0:
    print('positivo')
else:
    print('Cerapio')

# %%
dato = input('numero, por favor')
numero = int(dato)
if numero < 0:
    print(f'el numero {numero} es negativo')
elif numero > 0:
    print(f'el numero {numero} es positivo')
else:
    print(f'el numero {numero} es cero')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 dato = input('numero, por favor')
# ----> 2 numero = int(dato)
#       3 if numero < 0:
#       4     print(f'el numero {numero} es negativo')
#
# ValueError: invalid literal for int() with base 10: '1.5'

# %%
visitas_labolable = 150
importe_laborable = 637.5
visitas_festivos = 250
precio_entrada = importe_laborable / visitas_labolable
importe_efectivo = precio_entrada * visitas_festivos

print(importe_efectivo)

cosa = 2125 / precio_entrada
print(cosa)
# Out:
# 1062.5
# 500.0

# %% [markdown]
# ## Chequea la letra

# %%
cadena = "Supercalifragilisticoespialidoso"

letra = input('Dime una letra')

if letra in cadena:
    print(f'La letra {letra} esta en {cadena}')
else:
    print(f'La letra "{letra}" NO esta en {cadena}')
# Out:
# La letra t esta en Supercalifragilisticoespialidoso

# %%
cadena = '1,2,3,4,5,6,7,8,9,0'
lista = cadena.split(',')
lista
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '8', '9', '0']

# %%
'1' in lista
# Out:
# True

# %% [markdown]
# # Operadores

# %% [markdown]
# ### Operador Módulo

# %%
16%9
# Out:
# 7

# %% [markdown]
# ### Operador división entera

# %%
16 // 9
# Out:
# 1

# %% [markdown]
# ### Operador Exponente

# %%
5 ** 2
# Out:
# 25

# %%
27 ** (1/3)
# Out:
# 3.0

# %%
x = 1
y = 5
z = 3

if 1 < z < 5:
    pass

# %%
x = 2
x += 3
x *= 3
x /= 2

print(x)
# Out:
# 7.5
