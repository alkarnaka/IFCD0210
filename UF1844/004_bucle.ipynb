# %% [markdown]
# # Bucles

# %%
for i in range(10,1,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
lista = [1,2,3,4,5,6,7,8,9,0]

for numero in lista:
    print(numero)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 0
