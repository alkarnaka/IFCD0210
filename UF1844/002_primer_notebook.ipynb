# %% [markdown]
# # Introducción a Python

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %% [markdown]
# Calcular el índice de masa corporal
#
# IMC = Peso(kg) / altura ** 2
#
# imc < 18: Bajo
#
# 18 < imc < 25: Normal
#
# \> 25: Sobrepeso

# %%
peso = 57
altura = 1.77
imc = peso / altura ** 2
print(imc)
# Out:
# 18.194005553959588
